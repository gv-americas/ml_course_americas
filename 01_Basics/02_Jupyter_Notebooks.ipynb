# %% [markdown]
# A Jupyter Notebook is an interactive computational environment that combines code, rich text, and visualizations in a single document. It's like a digital laboratory where you can experiment, analyze data, and write code, all in one place.

# %% [markdown]
# Jupyter notebooks are based on cells. A cell can be a code cell or a markdown cell.

# %%
print("Hello World")

# %% [markdown]
# Markdown cells will accept headers (#, ##, ###, ...)

# %% [markdown]
# # Header 1

# %% [markdown]
# ## Header 2

# %% [markdown]
# You can also add equations using LaTeX notation:
#
# $$Z^*(u_0)=\sum_{n=1}^{n}\lambda_iz(u_i)$$

# %% [markdown]
# And also images:
#
# ![Matheron](matheron.jpg)

# %% [markdown]
# And tables:
#
# | Column 1 | Column 2 |
# |----------|----------|
# | row 1    | row 1    |
# | row 2    | row 2    |

# %% [markdown]
# Finally, you can add any unicode charachter, including emojis 😎
