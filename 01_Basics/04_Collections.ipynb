# %% [markdown]
# # Lists

# %%
l = list([1,2,3,4])

# %%
l

# %%
l = list('data')

# %%
l

# %%
l = ['data','mine','software']

# %%
l

# %%
l = ['data','mine','software', 2026]

# %%
l

# %% [markdown]
# ## Indexing

# %%
l[0]

# %%
l[-1]

# %%
l[0] = 'DATA'

# %%
l

# %%
l[50]

# %%
ll = [[1,2,3,4], [5,6,7,8]]

# %%
ll[0][1]

# %% [markdown]
# ## Slicing

# %% [markdown]
# lst[start:stop:step]

# %%
l[:]

# %%
l[::2]

# %%
l[1:3]

# %%
l[1:3] = ['MINE', 'SOFTWARE']

# %%
l

# %%
l[3:6]

# %%
l[3:6] = ['GEOVARIANCES', 'ISATIS', 'NEO']

# %%
l

# %%
l = [1,2,3,4,5,6,7,8]

# %%
l[::2]

# %% [markdown]
# ## Operations

# %%
l1 = ['data']
l2 = ['mine']

# %%
l1 + l2

# %%
l1 - l2

# %%
l1 * 3

# %%
l1 / 3

# %%
'data' in l1

# %% [markdown]
# ## Useful functions

# %% [markdown]
# * len(): Returns the number of characters in the string
# * max(): Returns the maximum value of a list
# * min(): Returns the minimum value of a list
# * sorted(): Sort the values of a list
# * sum(): Sums the elements of a list

# %%
len(l)

# %%
max([1,2,3,4,5])

# %%
sum([1,2,3,4,5])

# %%
sorted(l)

# %% [markdown]
# ## Useful methods

# %% [markdown]
# * append(): Adds an element at the end of the list
# * clear(): Removes all the elements from the list
# * copy(): Returns a copy of the list
# * count(): Returns the number of elements with the specified value
# * extend(): Add the elements of a list (or any iterable), to the end of the current list
# * index(): Returns the index of the first element with the specified value
# * insert(): Adds an element at the specified position
# * join(): Converts the elements of an iterable into a string
# * pop(): Removes the element at the specified position
# * remove(): Removes the first item with the specified value
# * reverse(): Reverses the order of the list
# * sort(): Sorts the list

# %%
l.append('2026')

# %%
l

# %%
l.pop(2)

# %%
l

# %%
l.remove('SOFTWARE')

# %%
l

# %%
l.index('DATA')

# %%
l.reverse()

# %%
l

# %%
'_'.join(l)

# %%
l.sort()

# %%
l

# %% [markdown]
# # Tuple

# %%
t = tuple([1,2,3,4])

# %%
t

# %%
t = (1,2,3,4)

# %%
t

# %% [markdown]
# # Dictionaries

# %%
d = dict(LIM=1, SAP=2, BRK=2)

# %%
d

# %%
d = {
    "LIM":1,
    "SAP":2,
    "BRK":3
}

# %%
thisdict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}

# %%
d

# %%
d['FSAP'] = 4

# %%
d

# %%
d['LIM'] = 0

# %%
d

# %% [markdown]
# ## Useful fucntions

# %% [markdown]
# * len(): Returns the number of characters in the string
# * sorted(): Sort the values of a list

# %%
sorted(d)

# %%
d

# %%
len(d)

# %% [markdown]
# ## Useful methods

# %% [markdown]
# * clear(): Removes all the elements from the dictionary
# * copy(): Returns a copy of the dictionary
# * get(): Returns the value of the specified key
# * items(): Returns a list containing a tuple for each key value pair
# * keys(): Returns a list containing the dictionary's keys
# * pop(): Removes the element with the specified key
# * popitem(): Removes the last inserted key-value pair
# * values(): Returns a list of all the values in the dictionary

# %%
d.get('LIM')

# %%
d.pop('BRK')

# %%
d

# %%
d.keys()

# %%
type(d.keys())

# %%
list(d.keys())

# %%
d.values()

# %% [markdown]
# # Exercises

# %% [markdown]
# Given the two list of list representing matrices write the matrix multiplication indexing the values. Ex.: `m1[0][0]*m2[0][0]`

# %% [markdown]
# <div>
# <img src="matmul.jpg" width="600"/>
# </div>

# %%
m1 = [[1,2,3],
      [4,5,6]]

m2 = [[10,11],
      [20,21],
      [30,31]]
