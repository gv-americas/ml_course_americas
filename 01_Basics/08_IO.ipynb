# %% [markdown]
# # Reading

# %%
file_path = r"..\00_Data\walker_lake_cat.csv"

# %%
f = open(file_path, 'r')

# %%
for line in f:
    print(line)

# %%
f = open(file_path, 'r')
f.read()

# %%
f = open(file_path, 'r')
f.readline()

# %%
f = open(file_path, 'r')
f.readlines()

# %%
f.close()

# %% [markdown]
# # Writing

# %%
file_path = r"..\00_Data\written_file.csv"

# %%
string_to_write = """
x,y,z,ni
100,120,130,1.6
200,250,110,0.9
110,105,147,1.8
"""

# %%
f = open(file_path, "w") #w (write), a (append) or x (error if file exists)

# %%
f.write(string_to_write)

# %%
f.close()

# %% [markdown]
# # User input

# %%
username = input("Enter username: ")

# %%
print("Username is: " + username)

# %% [markdown]
# # Exercises

# %% [markdown]
# Read the Exp_core.csv file. Create an empty nickel grades list. Fill this list with nickel grades. If xrf exists use it otherwise use aas At the end calculate the nickel mean using the function you already created.
#
# *Tip: use the split() string method and the float() fuction.*
