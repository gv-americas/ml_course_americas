# %% [markdown]
# # Importing modules

# %%
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # fit, transform and fit_transform methods

# %%
X_train = np.array([[10.0], [20.0], [30.0], [40.0]])

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

print("mean learned on training set:", scaler.mean_)
print("scaled training data:")
print(X_train_scaled)
# Out:
# mean learned on training set: [25.]
# scaled training data:
# [[-1.34164079]
#  [-0.4472136 ]
#  [ 0.4472136 ]
#  [ 1.34164079]]

# %% [markdown]
# # predict method

# %%
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 6, 8, 10])

model = LinearRegression()
model.fit(X, y)

print("coef_:", model.coef_)
print("intercept_:", model.intercept_)
print("prediction for 6:", model.predict([[6]]))
# Out:
# coef_: [2.]
# intercept_: -1.7763568394002505e-15
# prediction for 6: [12.]
